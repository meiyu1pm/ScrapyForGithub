# %%
def find_user_names():
    import pandas as pd
    return pd.read_csv('./noEmail.csv').username.to_list()

# %%
USER_NAME_LIST = find_user_names()

# %%
len(USER_NAME_LIST)
# Out:
# 6470

# %%
import csv
with open('./spiders/noEmail.csv') as csv_file:
    data = csv.reader(csv_file)
    user_name_list = [row[1] for row in data]

# %%
user_name_list
# Out:
# ['username',
#  'jisungk',
#  'chelseakomlo',
#  'N8python',
#  'rui1996',
#  'vgoklani',
#  'bossjones',
#  'TomNicholas',
#  'devexie',
#  'milkie',
#  'dantrauner',
#  'Jean13',
#  'hbcbh1999',
#  'hackingbutlegal',
#  'polyzen',
#  'CJ-Wright',
#  'marcdacosta',
#  'rowdywang',
#  'jasonligg',
#  'jkatz',
#  'eventuallyc0nsistent',
#  'yoavartzi',
#  'excelle08',
#  'riswandans',
#  'jfarley248',
#  'ArloGui',
#  'galvin-mj',
#  'jasoncoooks',
#  'zhangguanheng66',
#  'gaberger',
#  'stinky2nine',
#  'getmykhan',
#  'Trabing',
#  'mannatsingh',
#  'ynouri',
#  'AnastasiyaB',
#  'LongLong-Jing',
#  'radonys',
#  'ddaniels',
#  'njm2112',
#  'danromuald',
#  'RapidDNS',
#  'rjose2490',
#  'pliu',
#  'CindyXin97',
#  'fieldform',
#  'cjgodfather',
#  'notmahi',
#  'yl4579',
#  'adam410',
#  'veritas06',
#  'eunice-pereira',
#  'boubascript',
#  '0x45DDA458',
#  'SharpBit',
#  'blakme',
#  'zsmith928',
#  'ricardopineda93',
#  'TatianaTylosky',
#  'NinjaTG',
#  'rongutierrez',
# ...
