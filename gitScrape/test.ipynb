# %%
import pandas as pd

# %%
data = pd.read_csv('./gitUserInfo.csv')

# %%
data
# Out:
#                 username                                 gitUrl  \
# 0     alexandrebarachant  https://github.com/alexandrebarachant
# 1            viswanathgs         https://github.com/viswanathgs
# 2               luiscape            https://github.com/luiscape
# 3                TCWTEAM             https://github.com/TCWTEAM
# 4            TheShadow29         https://github.com/TheShadow29
# ...                  ...                                    ...
# 5987       IvanRivera212       https://github.com/IvanRivera212
# 5988  meduardoscervantes  https://github.com/meduardoscervantes
# 5989    IsaacDanielReyna    https://github.com/IsaacDanielReyna
# 5990         miketitan58         https://github.com/miketitan58
# 5991              xConde              https://github.com/xConde
#
#                                  name                            blog  \
# 0                 alexandre barachant  http://alexandre.barachant.org
# ...
